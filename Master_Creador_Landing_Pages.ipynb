# %% [markdown]
# # 🚀 Guía Maestra: El Mejor Creador de Landing Pages del Mundo
#
# Bienvenido a tu manual definitivo para transformar ideas en experiencias digitales de alta conversión y estética premium. Ser el mejor no se trata solo de escribir código, sino de dominar la **psicología, el diseño y la técnica**.
#
# ---

# %% [markdown]
# ## 1. 🧠 Psicología de Conversión: El Método AIDA
#
# Para que una landing page funcione, debe guiar al usuario por un camino emocional:
#
# 1.  **Atención (Attention)**: Un titular (H1) que resuelva un problema o despierte curiosidad en < 3 segundos.
# 2.  **Interés (Interest)**: Beneficios claros, no solo características. ¿Por qué le importa al usuario?
# 3.  **Deseo (Desire)**: Prueba social, testimonios o imágenes que aspiren a un estado mejor.
# 4.  **Acción (Action)**: Un CTA (Call to Action) único, claro y contrastado.

# %% [markdown]
# ## 💎 2. Estética Visual de Lujo
#
# El diseño premium separa a los aficionados de los expertos. Sigue estas reglas:
#
# ### 🎨 Colores (Sistema HSL)
# Evita colores planos. Usa HSL para control total sobre saturación y brillo:
# - `hsl(210, 30%, 15%)`: Un Navy elegante.
# - `hsl(45, 50%, 60%)`: Un Oro refinado.
# - Usa gradientes suaves: `linear-gradient(135deg, var(--color-1), var(--color-2))`.
#
# ### 🖋️ Tipografía
# - **H1/H2**: Serif (como *Playfair Display* o *Cormorant*) para elegancia.
# - **Cuerpo**: Sans-serif (como *Inter* o *Inter*) para legibilidad.
# - **Jerarquía**: Diferencia claramente los tamaños para guiar el ojo.

# %% [markdown]
# ## 🛠️ 3. Implementación con MCPs (Tu Arsenal Secreto)
#
# Como usuario avanzado de Antigravity, tienes herramientas que otros no:
#
# ### 🎨 Generación de Assets
# Usa `generate_image` para crear visuales únicos.
# *Prompt sugerido*: "Modern landing page hero section, minimalist luxury design, vibrant colors, glassmorphism UI, 8k resolution."
#
# ### 🏗️ Prototipado Rápido con Stitch
# Usa `mcp_stitch_generate_screen_from_text` para crear la estructura base en segundos. Luego refínala con tu toque personal en CSS.

# %% [markdown]
# ## 📋 4. Checklist Definitivo antes del Despliegue
#
# - [ ] **SEO**: ¿Tienes un solo H1? ¿Metadescripciones añadidas?
# - [ ] **Velocidad**: ¿Están las imágenes optimizadas?
# - [ ] **Responsivo**: ¿Se ve perfecto en un iPhone y en un monitor 4k?
# - [ ] **Micro-animaciones**: ¿Tienen los botones estados `hover` que se sientan vivos?
# - [ ] **Claridad**: Si un niño de 5 años la mira, ¿entiende qué se vende?
